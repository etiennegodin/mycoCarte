# %%
import geopandas as gpd
import pandas as pd
gdf = gpd.read_file('/home/egodin/Documents/projects/mycoCarte/data/raw/sampledBioclim/0.5km_bioclim.shp')

print(gdf.head())
# Out:
#    FID  bioclim_01  bioclim_02  bioclim_03   bioclim_04  bioclim_05  \
# 0    0    4.512500   11.691667   27.837301  1082.356689   25.200001
# 1    1    4.641667   11.716666   27.764614  1084.474854   25.400000
# 2    2    4.641667   11.716666   27.764614  1084.474854   25.400000
# 3    3    4.691667   11.733334   27.738377  1087.893799   25.500000
# 4    4    4.691667   11.733334   27.738377  1087.893799   25.500000
#
#    bioclim_06  bioclim_07  bioclim_08  bioclim_09  ...  bioclim_11  \
# 0  -16.799999   42.000000    6.733334   -3.433333  ...   -9.349999
# 1  -16.799999   42.199997    6.833333   -3.300000  ...   -9.250000
# 2  -16.799999   42.199997    6.833333   -3.300000  ...   -9.250000
# 3  -16.799999   42.299999    6.916667   -3.283333  ...   -9.250000
# 4  -16.799999   42.299999    6.916667   -3.283333  ...   -9.250000
#
#    bioclim_12  bioclim_13  bioclim_14  bioclim_15  bioclim_16  bioclim_17  \
# 0       926.0        91.0        55.0   14.472115       264.0       186.0
# ...

# %%
df = gdf.drop('geometry', axis = 1)
print(df.head())
# Out:
#    FID  bioclim_01  bioclim_02  bioclim_03   bioclim_04  bioclim_05  \
# 0    0    4.512500   11.691667   27.837301  1082.356689   25.200001
# 1    1    4.641667   11.716666   27.764614  1084.474854   25.400000
# 2    2    4.641667   11.716666   27.764614  1084.474854   25.400000
# 3    3    4.691667   11.733334   27.738377  1087.893799   25.500000
# 4    4    4.691667   11.733334   27.738377  1087.893799   25.500000
#
#    bioclim_06  bioclim_07  bioclim_08  bioclim_09  bioclim_10  bioclim_11  \
# 0  -16.799999   42.000000    6.733334   -3.433333   17.283333   -9.349999
# 1  -16.799999   42.199997    6.833333   -3.300000   17.450001   -9.250000
# 2  -16.799999   42.199997    6.833333   -3.300000   17.450001   -9.250000
# 3  -16.799999   42.299999    6.916667   -3.283333   17.533333   -9.250000
# 4  -16.799999   42.299999    6.916667   -3.283333   17.533333   -9.250000
#
#    bioclim_12  bioclim_13  bioclim_14  bioclim_15  bioclim_16  bioclim_17  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
 
corr = df.corr()
sns.heatmap(corr)
plt.show()

# %%
col_remove = ['bioclim_06',
              'bioclim_07',
              'bioclim_11',
              'bioclim_13',
              'bioclim_14',
              'bioclim_19']
